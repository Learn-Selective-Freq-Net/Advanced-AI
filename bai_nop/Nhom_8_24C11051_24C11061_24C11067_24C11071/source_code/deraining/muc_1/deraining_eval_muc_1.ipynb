# %% [markdown]
# # Mức 1: Đánh giá mô hình deraining (pretrained) trên dữ liệu từ bài báo
# **CHÚ Ý:**
# - Bật GPU T4 x2 trước khi chạy notebook
# - Thêm Kaggle dataset sau làm input: https://kaggle.com/datasets/64798bfa682c6404973c67c8febb76a39ff29c03494ab263fc15ee0dc4e2e67c

# %% [markdown]
# # Môi trường & Dependencies
# - Kaggle

# %%
# !cat /etc/*release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !sudo apt-get install libtinfo5
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libtinfo5
# 0 upgraded, 1 newly installed, 0 to remove and 132 not upgraded.
# Need to get 100 kB of archives.
# After this operation, 557 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Fetched 100 kB in 0s (764 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# Selecting previously unselected package libtinfo5:amd64.
# (Reading database ... 127365 files and directories currently installed.)
# Preparing to unpack .../libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# ...

# %%
# !python --version
# !python3.8 --version
# Out:
# Python 3.10.12
# /bin/bash: line 1: python3.8: command not found

# %%
# !sudo apt update
# !sudo apt install python3.8 python3.8-distutils
# !sudo apt install python3.8-dev
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [61.9 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,560 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,199 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# ...

# %%
# !python --version
# !python3.8 --version
# Out:
# Python 3.10.12
# Python 3.8.20

# %%
# %cd /kaggle
# !wget https://bootstrap.pypa.io/get-pip.py
# !sudo python3.8 get-pip.py
# Out:
# /kaggle
# --2025-01-13 07:09:18--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.192.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2275758 (2.2M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.17M  --.-KB/s    in 0.07s
#
# 2025-01-13 07:09:19 (31.6 MB/s) - ‘get-pip.py’ saved [2275758/2275758]
#
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.1 MB/s eta 0:00:00
# ...

# %%
# !pip --version
# !pip3.8 --version
# Out:
# pip 24.3.1 from /usr/local/lib/python3.8/dist-packages/pip (python 3.8)
# pip 24.3.1 from /usr/local/lib/python3.8/dist-packages/pip (python 3.8)

# %%
# !python3.8 -m pip install torch==1.8.1 torchvision==0.9.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.0/861.0 MB 22.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 93.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 136.7 MB/s eta 0:00:00
# ...

# %%
# !pip3.8 install tensorboard einops scikit-image pytorch_msssim opencv-python
# Out:
# ...
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# ...
#   Using cached pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 68.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 118.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 112.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 128.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 85.0 MB/s eta 0:00:00
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
# Using cached pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 100.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Tải source code

# %%
# %cd /kaggle
# !git clone https://github.com/c-yn/SFNet.git
# Out:
# /kaggle
# Cloning into 'SFNet'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 125 (delta 63), reused 63 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 157.26 KiB | 9.83 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# !ls /kaggle/
# Out:
# get-pip.py  input  lib	SFNet  working

# %% [markdown]
# # Kiểm tra dữ liệu đã thêm vào Kaggle Input

# %%
# !ls /kaggle/input/rrain13k-data-and-model/Rrain13K
# Out:
# deraining.pkl  deraining_testset  input  target

# %% [markdown]
# # Inference

# %%
# # %cd /content/drive/MyDrive/advanced_machine_learning/colab/SFNet/Motion_deblurring
# %cd /kaggle/SFNet
# %cd pytorch-gradual-warmup-lr/
# # !python3.8 setup.py install
# !python setup.py install
# # !python3.10 setup.py install
# %cd ..

# %%
# !cp /kaggle/SFNet/Image_dehazing/eval.py /kaggle/SFNet/Image_deraining
# !cp /kaggle/SFNet/Motion_deblurring/eval.py /kaggle/SFNet/Image_deraining

# %%
# %mkdir /kaggle/SFNet/Image_deraining/results

# %%
# %cd /kaggle/SFNet/Image_deraining
# %pwd
# %ls
# Out:
# /kaggle/SFNet/Image_deraining
# data/             main.py  README.md  test.py   utils.py
# deraining_test.m  models/  results/   train.py  valid.py

# %%
# !python test.py
# !python test.py --test_model /kaggle/input/rrain13k-data-and-model/Rrain13K/deraining.pkl --data_dir /kaggle/input/rrain13k-data-and-model/Rrain13K/deraining_testset # --model_save_dir /kaggle/working/output
# Out:
# /kaggle/SFNet/Image_deraining/test.py:84: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(args.test_model)
# results/SFNet/deraining/Rain100L
# ...

# %% [markdown]
# # Download dữ liệu
# - Kết quả đã được upload tại link: https://studenthcmusedu-my.sharepoint.com/:f:/g/personal/24c11071_student_hcmus_edu_vn/EvoN4KDb9wBNhnTmbmuSaT8BKKQl7RY_j_MwDv54ZpSinw?e=RaLkie

# %%
# !mv /kaggle/SFNet/Image_deraining/results /kaggle/working/results

# %%
# %cd /kaggle/working/results
# Out:
# /kaggle/working/results

# %%
# Zip kết quả inference
# !zip -r deraining_test_output.zip SFNet
# Out:
#   adding: SFNet/ (stored 0%)
#   adding: SFNet/deraining/ (stored 0%)
#   adding: SFNet/deraining/Rain100L/ (stored 0%)
#   adding: SFNet/deraining/Rain100L/98.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/57.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/44.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/96.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/80.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/91.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/60.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/65.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/68.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/66.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/93.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/92.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/20.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/83.png (deflated 0%)
#   adding: SFNet/deraining/Rain100L/13.png (deflated 0%)
# ...

# %%
# %cd /kaggle/input/rrain13k-data-and-model/Rrain13K/
# !ls
# Out:
# /kaggle/input/rrain13k-data-and-model/Rrain13K
# deraining.pkl  deraining_testset  input  target

# %% [markdown]
# # What's next?
# - Sau khi download dữ liệu được inference &rarr; Sử dụng code Matlab ([SFNet/Image_deraining/deraining_test.m](../../../docs/original_source_code/SFNet/Image_deraining/deraining_test.m)) để evaluate
# - Ghi chú cho Matlab:
#     - Có thể dùng online Matlab trial
#     - Bỏ các dòng có lời gọi hàm gcp nếu tài khoản Matlab không có license cho [Parallel Computing Toolbox](https://www.mathworks.com/products/parallel-computing.html) - a tool for performing parallel computations on multicore computers, GPUs, and clusters
