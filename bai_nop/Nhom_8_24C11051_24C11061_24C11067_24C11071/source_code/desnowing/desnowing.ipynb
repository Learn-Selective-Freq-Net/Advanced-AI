# %% [markdown]
# ## Setup python and sourcode

# %%
# !cat /etc/*release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
from IPython.display import clear_output

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
# !bash miniconda.sh -b -p /kaggle/working/miniconda
# !/kaggle/working/miniconda/bin/conda init
# !/kaggle/working/miniconda/bin/conda create -y -n py38 python=3.8
# !source /kaggle/working/miniconda/bin/activate py38
clear_output()                                                 
# !python --version
# Out:
# Python 3.10.12

# %%
# !ls /usr/bin/python3.*
# Out:
# /usr/bin/python3.10  /usr/bin/python3.10-config

# %%
# !/kaggle/working/miniconda/envs/py38/bin/python --version
# Out:
# Python 3.8.20

# %%
# !ls /usr/bin/python*
# Out:
# /usr/bin/python3     /usr/bin/python3.10-config
# /usr/bin/python3.10  /usr/bin/python3-config

# %%
# !sudo rm /usr/bin/python3.*
# !sudo ln -sf /kaggle/working/miniconda/envs/py38/bin/python /usr/bin/python3.8

# %%
# !sudo rm /usr/bin/python3
# !sudo ln -sf /kaggle/working/miniconda/envs/py38/bin/python /usr/bin/python3

# %%
# !sudo rm /usr/bin/python
# !sudo ln -sf /kaggle/working/miniconda/envs/py38/bin/python /usr/bin/python
# Out:
# rm: cannot remove '/usr/bin/python': No such file or directory

# %%
# !ls /usr/bin/python3.*
# Out:
# /usr/bin/python3.8

# %%
# !python --version
# !pip --version
# Out:
# Python 3.8.20
# pip 24.2 from /kaggle/working/miniconda/envs/py38/lib/python3.8/site-packages/pip (python 3.8)

# %%
# !pip install torch==1.8.1 torchvision==0.9.1 https://download.pytorch.org/whl/torch_stable.html
clear_output()

# %%
# !pip install tensorboard einops scikit-image pytorch_msssim opencv-python torchvision
clear_output()

# %%
# %cd /kaggle/working
# !git clone https://github.com/c-yn/SFNet.git
# Out:
# /kaggle/working
# Cloning into 'SFNet'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 131 (delta 67), reused 62 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (131/131), 159.09 KiB | 3.12 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
# !ls /kaggle/input/d/ducluuthien/snow-100k/Snow100K
# Out:
# test2000  train2500

# %%
# %cp -r /kaggle/input/sfnet-code /kaggle/working/
# %cd /kaggle/working
# !ls
# Out:
# /kaggle/working
# miniconda  miniconda.sh  SFNet

# %%
# %cd /kaggle/working/SFNet/pytorch-gradual-warmup-lr
# !ls
# !pip install . --user
# Out:
# /kaggle/working/SFNet/pytorch-gradual-warmup-lr
# setup.py  warmup_scheduler
# Processing /kaggle/working/SFNet/pytorch-gradual-warmup-lr
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for warmup_scheduler: filename=warmup_scheduler-0.3-py3-none-any.whl size=2971 sha256=4e0c66208d85f8ec6c375056fc8e7627bfb86c5388b345b95ea30585d630a757
#   Stored in directory: /root/.cache/pip/wheels/a0/08/5d/e27714011c0d657c5aaa3fa8b95beec5735afd0cbc428d4b7b
# Successfully built warmup_scheduler
# ...

# %% [markdown]
# ## Run Model train from Snow100K

# %% [markdown]
# ### With Snow100K Test Dataset

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from SRRS on test data of SNOW100K
# !python main.py --data Snow100K --save_image False --mode test --data_dir /kaggle/input/d/ducluuthien/snow-100k/Snow100K --test_model /kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/    main.py  __pycache__/  results/  train.py  valid.py
# eval.py  models/  README.md     runs/     utils.py
# Namespace(batch_size=4, data='Snow100K', data_dir='/kaggle/input/d/ducluuthien/snow-100k/Snow100K', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/Snow100K', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl', valid_freq=20, weight_decay=0)
# ...

# %% [markdown]
# ### With Kitti-Small Test Dataset

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from Snow100K on test data of Kitti
# !python main.py --data Snow100K --save_image True --mode test --data_dir /kaggle/input/kitti-dataset/Kitti --test_model /kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/  eval.py  main.py  models/  README.md  train.py  utils.py  valid.py
# Namespace(batch_size=4, data='Snow100K', data_dir='/kaggle/input/kitti-dataset/Kitti', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/Snow100K', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl', valid_freq=20, weight_decay=0)
# ...

# %% [markdown]
# ### With Kitti-large DATASET

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from Snow100K on test data of Kitti-large
# !python main.py --data Snow100K --save_image True --mode test --data_dir /kaggle/input/kitti-large/Kitti-large --test_model /kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/    main.py  output.zip    README.md  train.py  valid.py
# eval.py  models/  __pycache__/  results/   utils.py
# Namespace(batch_size=4, data='Snow100K', data_dir='/kaggle/input/kitti-large/Kitti-large', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/Snow100K', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl', valid_freq=20, weight_decay=0)
# ...

# %% [markdown]
# ### With SRRS Test Dataset

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from Snow100K on test data of SRRS
# !python main.py --data SRRS --save_image False --mode test --data_dir /kaggle/input/srrs-dataset/SRRS\(2000\) --test_model /kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/  eval.py  main.py  models/  README.md  train.py  utils.py  valid.py
# Namespace(batch_size=4, data='SRRS', data_dir='/kaggle/input/srrs-dataset/SRRS(2000)', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/SRRS', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl', valid_freq=20, weight_decay=0)
# ...

# %% [markdown]
# ### With CSD2000 Test Dataset

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from Snow100K on test data of SRRS
# !python main.py --data CSD --save_image False --mode test --data_dir /kaggle/input/csd-2000/CSD --test_model /kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/    main.py  __pycache__/  results/  utils.py
# eval.py  models/  README.md     train.py  valid.py
# Namespace(batch_size=4, data='CSD', data_dir='/kaggle/input/csd-2000/CSD', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/CSD', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/snow-100k/pytorch/default/1/Snow100K.pkl', valid_freq=20, weight_decay=0)
# ...

# %% [markdown]
# ## Run Model train from SRRS

# %% [markdown]
# ### With SRRS Test Dataset

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from SRRS on test data of SRRS
# !python main.py --data SRRS --save_image False --mode test --data_dir /kaggle/input/srrs-dataset/SRRS\(2000\) --test_model /kaggle/input/srrs-model/pytorch/default/1/SRRS.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/    main.py  __pycache__/  results/  utils.py
# eval.py  models/  README.md     train.py  valid.py
# Namespace(batch_size=4, data='SRRS', data_dir='/kaggle/input/srrs-dataset/SRRS(2000)', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/SRRS', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/srrs-model/pytorch/default/1/SRRS.pkl', valid_freq=20, weight_decay=0)
# ...

# %% [markdown]
# ### With SNOW100K Test Dataset

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from SRRS on test data of SNOW100K
# !python main.py --data Snow100K --save_image False --mode test --data_dir /kaggle/input/d/ducluuthien/snow-100k/Snow100K --test_model /kaggle/input/srrs-model/pytorch/default/1/SRRS.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/    main.py  __pycache__/  results/  utils.py
# eval.py  models/  README.md     train.py  valid.py
# Namespace(batch_size=4, data='Snow100K', data_dir='/kaggle/input/d/ducluuthien/snow-100k/Snow100K', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/Snow100K', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/srrs-model/pytorch/default/1/SRRS.pkl', valid_freq=20, weight_decay=0)
# ...

# %% [markdown]
# ### With CSD2000 Test Dataset

# %%
# %cd /kaggle/working/SFNet/Image_desnowing
# %pwd
# %ls

# Run Model train from SRRS on test data of SNOW100K
# !python main.py --data CSD --save_image False --mode test --data_dir /kaggle/input/csd-2000/CSD --test_model /kaggle/input/srrs-model/pytorch/default/1/SRRS.pkl
# Out:
# /kaggle/working/SFNet/Image_desnowing
# data/    main.py  __pycache__/  results/  utils.py
# eval.py  models/  README.md     train.py  valid.py
# Namespace(batch_size=4, data='CSD', data_dir='/kaggle/input/csd-2000/CSD', learning_rate=0.0001, mode='test', model_name='SFNet', model_save_dir='results/SFNet/Training-Results/', num_epoch=800, num_worker=8, print_freq=100, result_dir='results/SFNet/images/CSD', resume='', save_freq=20, save_image=True, test_model='/kaggle/input/srrs-model/pytorch/default/1/SRRS.pkl', valid_freq=20, weight_decay=0)
# ...
