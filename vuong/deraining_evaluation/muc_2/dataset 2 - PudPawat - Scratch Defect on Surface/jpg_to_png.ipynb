# %%
defect_dir = "./defect/"
non_defect_dir = "./non defect selection renamed/"

# %%
png_dir = "./png/"

# %%
# !pip install opencv-python
# !pip install pillow

# %%
# Convert all images to png
import os
import cv2
import numpy as np
from PIL import Image

def convert_to_png(input_dir, output_dir):
    for filename in os.listdir(input_dir):
        if filename.endswith(".jpg"):
            img = cv2.imread(input_dir + filename)
            png_file_path = output_dir + filename[:-4] + ".png"
            cv2.imwrite(png_file_path, img)

            print("Converted " + filename + " to " + png_file_path)

# %%
convert_to_png(defect_dir, f"{png_dir}input/")
# Out:
# Converted pic.2.68.jpg to ./png/input/pic.2.68.png
# Converted pic.2.853.jpg to ./png/input/pic.2.853.png
# Converted pic.2.106.jpg to ./png/input/pic.2.106.png
# Converted pic.2.674.jpg to ./png/input/pic.2.674.png
# Converted pic.2.97.jpg to ./png/input/pic.2.97.png
# Converted pic.2.270.jpg to ./png/input/pic.2.270.png
# Converted pic.2.1805.jpg to ./png/input/pic.2.1805.png
# Converted pic.2.1804.jpg to ./png/input/pic.2.1804.png
# Converted pic.2.271.jpg to ./png/input/pic.2.271.png
# Converted pic.2.1637.jpg to ./png/input/pic.2.1637.png
# Converted pic.2.729.jpg to ./png/input/pic.2.729.png
# Converted pic.2.1384.jpg to ./png/input/pic.2.1384.png
# Converted pic.2.96.jpg to ./png/input/pic.2.96.png
# Converted pic.2.675.jpg to ./png/input/pic.2.675.png
# Converted pic.2.107.jpg to ./png/input/pic.2.107.png
# Converted pic.2.69.jpg to ./png/input/pic.2.69.png
# Converted pic.2.311.jpg to ./png/input/pic.2.311.png
# Converted pic.2.307.jpg to ./png/input/pic.2.307.png
# ...

# %%
convert_to_png(non_defect_dir, f"{png_dir}target/")
# Out:
# Converted pic.2.68.jpg to ./png/target/pic.2.68.png
# Converted pic.2.853.jpg to ./png/target/pic.2.853.png
# Converted pic.2.106.jpg to ./png/target/pic.2.106.png
# Converted pic.2.674.jpg to ./png/target/pic.2.674.png
# Converted pic.2.97.jpg to ./png/target/pic.2.97.png
# Converted pic.2.270.jpg to ./png/target/pic.2.270.png
# Converted pic.2.1805.jpg to ./png/target/pic.2.1805.png
# Converted pic.2.1804.jpg to ./png/target/pic.2.1804.png
# Converted pic.2.271.jpg to ./png/target/pic.2.271.png
# Converted pic.2.1637.jpg to ./png/target/pic.2.1637.png
# Converted pic.2.729.jpg to ./png/target/pic.2.729.png
# Converted pic.2.1384.jpg to ./png/target/pic.2.1384.png
# Converted pic.2.96.jpg to ./png/target/pic.2.96.png
# Converted pic.2.675.jpg to ./png/target/pic.2.675.png
# Converted pic.2.107.jpg to ./png/target/pic.2.107.png
# Converted pic.2.69.jpg to ./png/target/pic.2.69.png
# Converted pic.2.311.jpg to ./png/target/pic.2.311.png
# ...
